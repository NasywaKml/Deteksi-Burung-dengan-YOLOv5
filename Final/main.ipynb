# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
# Import libraries
import os
from IPython.display import Image

# Path ke YOLOv5
os.chdir("../yolov5")  # Ubah jika path berbeda

# Training YOLOv5
# !python train.py --img 640 --batch 16 --epochs 50 --data ../data.yaml --weights yolov5s.pt --name yolo_v5_bounding_box
# Out:
# Error decoding JSON from C:\Users\booma\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\booma\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\booma\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING  wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8s.pt')  # Model YOLOv8 pre-trained (bisa 'yolov8m.pt' atau lainnya)
model.train(data='../data.yaml', epochs=50, batch=16, imgsz=640, name='yolo_v8_bounding_box')

metrics = model.val()
print(metrics)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:04<00:00, 5.42MB/s]
# New https://pypi.org/project/ultralytics/8.3.69 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.33  Python-3.12.2 torch-2.2.0+cpu CPU (12th Gen Intel Core(TM) i7-12650H)
# ...

# %%
results = model.predict(source='./test/image', conf=0.25, save=True)
